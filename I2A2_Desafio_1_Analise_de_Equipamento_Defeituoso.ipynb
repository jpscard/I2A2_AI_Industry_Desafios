# %% [markdown]
# <a href="https://colab.research.google.com/github/jpscard/I2A2_AI_Industry_Desafios/blob/main/I2A2_Desafio_1_Analise_de_Equipamento_Defeituoso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *Desafio 1 - I2A2 - ABDI*
# ### *Aluno:João Paulo da Silva Cardoso*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## *1. Importando bibliotecas*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## *2. Carregamento e visualização do dataset*

# %% [markdown]
# ### *2.1 Carregando dataset*

# %%
data = [
    [375,   135,    475,    509,    336,    492,    458,    469,    379,    343],
    [57,    47,     73,     63,     62,     58,     53,     63,     58,     63],
    [245,   267,    227,    271,    219,    286,    242,    268,    247,    223],
    [1472,  1494,   1582,   1613,   1323,   1493,   1462,   1490,   1487,   1349],
    [105,   66,     103,    118,    98,     118,    103,    101,    106,    100],
    [54,    41,     64,     55,     59,     59,     62,     63,     55,     60],
    [193,   209,    235,    207,    172,    156,    184,    223,    195,    175],
    [147,   93,     160,    139,    130,    101,    122,    152,    148,    133],
    [1102,  674,    1137,   1058,   990,    878,    957,    1098,   1113,   1010],
    [720,   1033,   874,    628,    646,    320,    566,    706,    727,    659],
    [253,   143,    265,    193,    226,    99,     171,    247,    256,    231],
    [685,   586,    803,    830,    615,    777,    750,    699,    692,    627],
    [488,   355,    570,    465,    437,    313,    418,    467,    493,    446],
    [198,   187,    203,    247,    176,    204,    220,    209,    200,    180],
    [360,   334,    365,    376,    322,    348,    337,    363,    364,    328],
    [1374,  1506,   1256,   1734,   1235,   1684,   1572,   1597,   1388,   1260],
    [156,   139,    175,    167,    138,    170,    147,    164,    158,    141],
]

# Definindo dataframe
df = pd.DataFrame(data, index=range(1,18), columns=['Obj1', 'Obj2', 'Obj3', 'Obj4', 'Obj5', 'Obj6', 'Obj7', 'Obj8', 'Obj9', 'Obj10',])

# Exibir o dataframe
display(df)
# Out:
#     Obj1  Obj2  Obj3  Obj4  Obj5  Obj6  Obj7  Obj8  Obj9  Obj10
# 1    375   135   475   509   336   492   458   469   379    343
# 2     57    47    73    63    62    58    53    63    58     63
# 3    245   267   227   271   219   286   242   268   247    223
# 4   1472  1494  1582  1613  1323  1493  1462  1490  1487   1349
# 5    105    66   103   118    98   118   103   101   106    100
# 6     54    41    64    55    59    59    62    63    55     60
# 7    193   209   235   207   172   156   184   223   195    175
# 8    147    93   160   139   130   101   122   152   148    133
# 9   1102   674  1137  1058   990   878   957  1098  1113   1010
# 10   720  1033   874   628   646   320   566   706   727    659
# 11   253   143   265   193   226    99   171   247   256    231
# 12   685   586   803   830   615   777   750   699   692    627
# 13   488   355   570   465   437   313   418   467   493    446
# 14   198   187   203   247   176   204   220   209   200    180
# ...

# %% [markdown]
# ### *2.2 Informações e estatísticas sobre os dados*

# %%
#Estatística básica
df.describe()
# Out:
#               Obj1         Obj2         Obj3         Obj4         Obj5  \
# count    17.000000    17.000000    17.000000    17.000000    17.000000
# mean    469.647059   429.941176   503.941176   510.176471   422.588235
# std     452.701466   479.896014   463.859282   517.552562   405.843267
# min      54.000000    41.000000    64.000000    55.000000    59.000000
# 25%     156.000000   135.000000   175.000000   167.000000   138.000000
# 50%     253.000000   209.000000   265.000000   271.000000   226.000000
# 75%     685.000000   586.000000   803.000000   628.000000   615.000000
# max    1472.000000  1506.000000  1582.000000  1734.000000  1323.000000
#
#               Obj6         Obj7         Obj8         Obj9        Obj10
# count    17.000000    17.000000    17.000000    17.000000    17.000000
# mean    444.470588   460.235294   492.882353   474.470588   431.058824
# std     491.302748   469.595907   480.721448   457.236552   413.938019
# ...

# %%
#mediana
df.median()
# Out:
# Obj1     253.0
# Obj2     209.0
# Obj3     265.0
# Obj4     271.0
# Obj5     226.0
# Obj6     286.0
# Obj7     242.0
# Obj8     268.0
# Obj9     256.0
# Obj10    231.0
# dtype: float64

# %%
#informações gerais
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 1 to 17
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Obj1    17 non-null     int64
#  1   Obj2    17 non-null     int64
#  2   Obj3    17 non-null     int64
#  3   Obj4    17 non-null     int64
#  4   Obj5    17 non-null     int64
#  5   Obj6    17 non-null     int64
#  6   Obj7    17 non-null     int64
#  7   Obj8    17 non-null     int64
#  8   Obj9    17 non-null     int64
#  9   Obj10   17 non-null     int64
# dtypes: int64(10)
# memory usage: 1.5 KB

# %%
#forma do dataset
df.shape
# Out:
# (17, 10)

# %% [markdown]
# ## *3. Etapa de Pré-processamento*

# %% [markdown]
# ### *3.1 Verificando valores nulos e duplicados nos dados*

# %%
df.isnull().sum().sort_values()
# Out:
# Obj1     0
# Obj2     0
# Obj3     0
# Obj4     0
# Obj5     0
# Obj6     0
# Obj7     0
# Obj8     0
# Obj9     0
# Obj10    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## *4. Análise exploratória dos dados*

# %% [markdown]
# ### *4.1 Boxplot*

# %%
boxplot = df.boxplot(column=['Obj1', 'Obj2', 'Obj3', 'Obj4', 'Obj5', 'Obj6', 'Obj7', 'Obj8', 'Obj9', 'Obj10'], patch_artist=False)

# %% [markdown]
# ### *4.2 Gráficos de Segmento*

# %%
df.plot(subplots =True, sharex = True, figsize = (10,13));

# %%
for i in df.columns:
    plt.plot(df[i], label=str(i))
    plt.legend()
plt.xlabel('Sensores')
plt.ylabel('Medidas')
plt.show()

# %% [markdown]
# ### *4.3 Matriz de correlação*

# %%
f, ax = plt.subplots(figsize = (10,6))
sns.heatmap(df.corr(), annot = True, fmt=".4f", linewidths=.6)
plt.show()

# %% [markdown]
# ## *5. Considerações finais*

# %% [markdown]
# ### *Atribuindo-se que os equipamentos possuem os mesmos sensores e que atuam em condições semelhantes, a métrica adotada foi analisar qual equipamento opera com menos padrões similares, quando comparado aos demais.*
#
# ### *Pouco se visualiza, quanto a diferenças significativas, com a estatística básica fornecida pelo "describe" (média, min, máx etc). Já com o boxplot, nota-se que o equipamentos Obj2 possui menor mediana e Obj8, maior.*
#
# ### *Através dos gráfico de segmento, observou-se diferenças relevantes em alguns sensores do equipamento Obj2 em relação aos outros, assim como, em alguns sensores de Obj8, porém, menos expressivos.*
#
# ### *Com a matriz de correlação, pode-se concluir que o equipamento Obj2 possui menor grau de correlação com os demais equipamentos medidos. Portanto, é possível inferir, perante a métrica adotada, que Obj2 seria o equipamento com defeito.*
