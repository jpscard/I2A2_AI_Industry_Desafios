# %% [markdown]
# <a href="https://colab.research.google.com/github/jpscard/I2A2_AI_Industry_Desafios/blob/main/I2A2%20Desafio%201%20-%20Analise%20de%20sensores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *Desafio 1 - I2A2 - ABDI*
# ### *Aluno:João Paulo da Silva Cardoso*

# %% [markdown]
# ![WhatsApp Image 2023-01-17 at 17.25.56.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## *1. Importando bibliotecas*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## *2. Carregamento e visualização do dataset*

# %% [markdown]
# ### *2.1 Carregando dataset*

# %%
df = pd.read_excel('/content/Defective_Equipment (revised).xlsx')
display(df)
# Out:
#     Seq    V1    V2    V3    V4    V5    V6    V7    V8
# 0     1   375   135   458   475   509   336   469   492
# 1     2    57    47    53    73    63    62    63    58
# 2     3   245   267   242   227   271   219   268   286
# 3     4  1472  1494  1462  1582  1613  1323  1490  1493
# 4     5   105    66   103   103   118    98   101   118
# 5     6    54    41    62    64    55    59    63    59
# 6     7   193   209   184   235   207   172   223   156
# 7     8   147    93   122   160   139   130   152   101
# 8     9  1102   674   957  1137  1058   990  1098   878
# 9    10   720  1033   566   874   628   646   706   320
# 10   11   253   143   171   265   193   226   247    99
# 11   12   685   586   750   803   830   615   699   777
# 12   13   488   355   418   570   465   437   467   313
# 13   14   198   187   220   203   247   176   209   204
# 14   15   360   334   337   365   376   322   363   348
# 15   16  1374  1506  1572  1256  1734  1235  1597  1684
# ...

# %% [markdown]
# ### *2.2 Removendo a coluna inicial*

# %%
df = df.drop(['Seq'], axis =1)
display(df)
# Out:
#       V1    V2    V3    V4    V5    V6    V7    V8
# 0    375   135   458   475   509   336   469   492
# 1     57    47    53    73    63    62    63    58
# 2    245   267   242   227   271   219   268   286
# 3   1472  1494  1462  1582  1613  1323  1490  1493
# 4    105    66   103   103   118    98   101   118
# 5     54    41    62    64    55    59    63    59
# 6    193   209   184   235   207   172   223   156
# 7    147    93   122   160   139   130   152   101
# 8   1102   674   957  1137  1058   990  1098   878
# 9    720  1033   566   874   628   646   706   320
# 10   253   143   171   265   193   226   247    99
# 11   685   586   750   803   830   615   699   777
# 12   488   355   418   570   465   437   467   313
# 13   198   187   220   203   247   176   209   204
# 14   360   334   337   365   376   322   363   348
# 15  1374  1506  1572  1256  1734  1235  1597  1684
# 16   156   139   147   175   167   138   164   170

# %% [markdown]
# ### *2.2 Informações e estatísticas sobre os dados*

# %%
#Estatística básica
df.describe()
# Out:
#                 V1           V2           V3           V4           V5  \
# count    17.000000    17.000000    17.000000    17.000000    17.000000
# mean    469.647059   429.941176   460.235294   503.941176   510.176471
# std     452.701466   479.896014   469.595907   463.859282   517.552562
# min      54.000000    41.000000    53.000000    64.000000    55.000000
# 25%     156.000000   135.000000   147.000000   175.000000   167.000000
# 50%     253.000000   209.000000   242.000000   265.000000   271.000000
# 75%     685.000000   586.000000   566.000000   803.000000   628.000000
# max    1472.000000  1506.000000  1572.000000  1582.000000  1734.000000
#
#                 V6           V7           V8
# count    17.000000    17.000000    17.000000
# mean    422.588235   492.882353   444.470588
# std     405.843267   480.721448   491.302748
# min      59.000000    63.000000    58.000000
# 25%     138.000000   164.000000   118.000000
# 50%     226.000000   268.000000   286.000000
# ...

# %%
#mediana
df.median()
# Out:
# V1    253.0
# V2    209.0
# V3    242.0
# V4    265.0
# V5    271.0
# V6    226.0
# V7    268.0
# V8    286.0
# dtype: float64

# %%
#informações gerais
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      17 non-null     int64
#  1   V2      17 non-null     int64
#  2   V3      17 non-null     int64
#  3   V4      17 non-null     int64
#  4   V5      17 non-null     int64
#  5   V6      17 non-null     int64
#  6   V7      17 non-null     int64
#  7   V8      17 non-null     int64
# dtypes: int64(8)
# memory usage: 1.2 KB

# %%
#forma do dataset
df.shape
# Out:
# (17, 8)

# %% [markdown]
# ## *3. Etapa de Pré-processamento*

# %% [markdown]
# ### *3.1 Verificando valores nulos e duplicados nos dados*

# %%
df.isnull().sum().sort_values()
# Out:
# V1    0
# V2    0
# V3    0
# V4    0
# V5    0
# V6    0
# V7    0
# V8    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## *4. Análise exploratória dos dados*

# %% [markdown]
# ### *4.1 Boxplot*

# %%
boxplot = df.boxplot(column=['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8'], patch_artist=False)

# %% [markdown]
# ### *4.2 Gráficos de Segmento*

# %%
df.plot(subplots =True, sharex = True, figsize = (10,13));

# %%
for i in df.columns:
    plt.plot(df[i], label=str(i))
    plt.legend()
plt.xlabel('Sensores')
plt.ylabel('Medidas')
plt.show()

# %% [markdown]
# ### *4.3 Matriz de correlação*

# %%
f, ax = plt.subplots(figsize = (10,6))
sns.heatmap(df.corr(), annot = True, fmt=".4f", linewidths=.6)
plt.show()

# %% [markdown]
# ## *5. Considerações finais*

# %% [markdown]
# ### *Atribuindo-se que os equipamentos possuem os mesmos sensores e que atuam em condições semelhantes, a métrica adotada foi analisar qual equipamento opera com menos padrões similares, quando comparado aos demais.*
#
# ### *Pouco se visualiza, quanto a diferenças significativas, com a estatística básica fornecida pelo "describe" (média, min, máx etc). Já com o boxplot, nota-se que o equipamentos V2 possui menor mediana e V8, maior.*
#
# ### *Através dos gráfico de segmento, observou-se diferenças relevantes em alguns sensores do equipamento V2 em relação aos outros, assim como, em alguns sensores de V8, porém, menos expressivos.*
#
# ### *Com a matriz de correlação, pode-se concluir que o equipamento V2 possui menor grau de correlação com os demais equipamentos medidos. Portanto, é possível inferir, perante a métrica adotada, que V2 seria o equipamento com defeito.*
